# %%
from qiskit import QuantumCircuit

# %%
phi = QuantumCircuit(2)
phi.h(0)
phi.cx(0, 1)
phi.draw('mpl')

# %%
# !pip3 install qiskit_aer
# Out:
# Collecting qiskit_aer
#   Downloading qiskit_aer-0.17.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in ./quantum_computing/lib/python3.9/site-packages (from qiskit_aer) (2.2.3)
# Requirement already satisfied: numpy>=1.16.3 in ./quantum_computing/lib/python3.9/site-packages (from qiskit_aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in ./quantum_computing/lib/python3.9/site-packages (from qiskit_aer) (1.13.1)
# Requirement already satisfied: psutil>=5 in ./quantum_computing/lib/python3.9/site-packages (from qiskit_aer) (7.2.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./quantum_computing/lib/python3.9/site-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./quantum_computing/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in ./quantum_computing/lib/python3.9/site-packages (from qiskit>=1.1.0->qiskit_aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in ./quantum_computing/lib/python3.9/site-packages (from qiskit>=1.1.0->qiskit_aer) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in ./quantum_computing/lib/python3.9/site-packages (from qiskit>=1.1.0->qiskit_aer) (5.5.0)
# Requirement already satisfied: typing-extensions in ./quantum_computing/lib/python3.9/site-packages (from qiskit>=1.1.0->qiskit_aer) (4.15.0)
# Downloading qiskit_aer-0.17.2-cp39-cp39-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 232.2 kB/s  0:00:09289.3 kB/s eta 0:00:01
# Installing collected packages: qiskit_aer
# Successfully installed qiskit_aer-0.17.2

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

phi.measure_all()

sim = AerSimulator()

tqc = transpile(phi, sim)
result = sim.run(tqc, shots=1024).result()

counts = result.get_counts()

plot_histogram(counts)

# %% [markdown]
# # GHZ State

# %%
qc = QuantumCircuit(3)

qc.h(0)
qc.cx(0, 1)
qc.cx(0, 2)

qc.draw('latex')
# Out:
# <PIL.Image.Image image mode=RGB size=206x85>

# %% [markdown]
# # Two qubit cluster state

# %%
qc = QuantumCircuit(2)

qc.h(0)

qc.h(1)

qc.cz(0, 1)

qc.draw('mpl')


qc.measure_all()

tqc = transpile(qc, sim)
result = sim.run(tqc, shots=1024).result()

counts = result.get_counts()

plot_histogram(counts)

# %%
from qiskit.visualization import plot_bloch_multivector

sim = AerSimulator(method="statevector")
qc = QuantumCircuit(2)

qc.h(0)

qc.h(1)

qc.cz(0, 1)

qc.draw('mpl')

qc.save_statevector()

tqc = transpile(qc, sim)
result = sim.run(tqc, shots=1024).result()

state = result.get_statevector()
state.draw('latex')

plot_bloch_multivector(state)
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[62], line 20
#      17 result = sim.run(tqc, shots=1024).result()
#      19 state = result.get_statevector()
# ---> 20 state.draw('latex')
#      22 plot_bloch_multivector(state)
#
# File ~/Study/mtech/assignments/QC/quantum_computing/lib/python3.9/site-packages/qiskit/quantum_info/states/statevector.py:196, in Statevector.draw(self, output, **drawer_args)
#     193 # pylint: disable=cyclic-import
#     194 from qiskit.visualization.state_visualization import state_drawer
# --> 196 return state_drawer(self, output=output, **drawer_args)
#
# File ~/Study/mtech/assignments/QC/quantum_computing/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:1484, in state_drawer(state, output, **drawer_args)
#    1481     from IPython.display import Latex
#    1483     draw_func = drawers["latex_source"]
# -> 1484     return Latex(f"$${draw_func(state, **drawer_args)}$$")
#    1486 if output == "repr":
#    1487     return state.__repr__()
#
# File ~/Study/mtech/assignments/QC/quantum_computing/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:1302, in state_to_latex(state, dims, convention, **args)
#    1300 is_qubit_statevector = len(operator_shape.dims_r()) == 0 and set(operator_shape.dims_l()) == {2}
#    1301 if convention == "ket" and is_qubit_statevector:
# -> 1302     latex_str = _state_to_latex_ket(state._data, **args)
#    1303 else:
#    1304     latex_str = array_to_latex(state._data, source=True, **args)
#
# File ~/Study/mtech/assignments/QC/quantum_computing/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:1357, in _state_to_latex_ket(data, max_size, prefix, decimals)
#    1355     nonzero_indices[max_size // 2] = None
#    1356 else:
# -> 1357     latex_terms = _numbers_to_latex_terms(data[nonzero_indices], decimals)
#    1359 latex_str = ""
#    1360 for idx, ket_idx in enumerate(nonzero_indices):
#
# File ~/Study/mtech/assignments/QC/quantum_computing/lib/python3.9/site-packages/qiskit/visualization/state_visualization.py:1322, in _numbers_to_latex_terms(numbers, decimals)
#    1320 terms = []
#    1321 for number in numbers:
# -> 1322     term = _num_to_latex(number, decimals=decimals, first_term=first_term, coefficient=True)
#    1323     terms.append(term)
#    1324     first_term = False
#
# File ~/Study/mtech/assignments/QC/quantum_computing/lib/python3.9/site-packages/qiskit/utils/lazy_tester.py:148, in LazyDependencyManager.require_in_call.<locals>.decorator.<locals>.out(*args, **kwargs)
#     146 @functools.wraps(function)
#     147 def out(*args, **kwargs):
# --> 148     self.require_now(feature)
#     149     return function(*args, **kwargs)
#
# File ~/Study/mtech/assignments/QC/quantum_computing/lib/python3.9/site-packages/qiskit/utils/lazy_tester.py:221, in LazyDependencyManager.require_now(self, feature)
#     219 if self:
#     220     return
# --> 221 raise MissingOptionalLibraryError(
#     222     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     223 )
#
# MissingOptionalLibraryError: "The 'sympy' library is required to use 'Create a latex representation of a ket expression'. You can install it with 'pip install sympy'."

# %%
state.draw()
# Out:
# 'Statevector([ 0.5+0.j,  0.5+0.j,  0.5+0.j, -0.5+0.j],\n            dims=(2, 2))'
